# %%
import torch
from torch import nn
import numpy as np
import os
from pyDOE import lhs
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib_inline import backend_inline
import time
import math

# %%
backend_inline.set_matplotlib_formats("svg")
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"


class MLP(nn.Module):
    def __init__(self, lst: list, act: callable = nn.Tanh):
        super().__init__()
        depth = len(lst) - 1
        layer = []
        for i in range(depth - 1):
            linear = nn.Linear(lst[i], lst[i + 1])
            layer.append(linear)
            layer.append(act())
        layer.append(nn.Linear(lst[-2], lst[-1]))
        self.layer = nn.Sequential(*layer)

    def forward(self, X):
        return self.layer(X)


model = MLP([2] + [50] * 4 + [1]).cuda()

# %%
from scipy.io import loadmat

model.load_state_dict(torch.load("./Best_Allen.pt"))
# model.load_state_dict(torch.load("/hy-tmp/CL+SAPINN_AC/Best_SAPINN_PINN.pt"))
p = np.linspace(-1, 1, 201)
q = np.linspace(0, 1, 101)
P, Q = np.meshgrid(p, q, indexing="ij")
datasets = np.concatenate([P.flatten()[:, None], Q.flatten()[:, None]], 1)
Truth = loadmat("./Allen_Cahn_0.001.mat")["u"].reshape(101, 201).T
preds = (
    model(torch.tensor(data=datasets, dtype=torch.float32).cuda())
    .cpu()
    .detach()
    .numpy()
    .reshape(201, 101)
)
extent = [0, 1, -1, 1]
figs, ax = plt.subplots(1, 3, figsize=(16, 4))
ax1, ax2, ax3 = ax[0], ax[1], ax[2]

h1 = ax1.imshow(Truth, cmap="jet", aspect="auto", extent=extent)
ax1.set_title("Truth")
ax1.set_xlabel("T")
ax1.set_ylabel("X")
figs.colorbar(h1, ax=ax1, shrink=0.5, aspect=30, pad=0.05)


h2 = ax2.imshow(preds, cmap="jet", aspect="auto", extent=extent)
ax2.set_title("Preds")
ax2.set_xlabel("T")
ax2.set_ylabel("X")
figs.colorbar(h2, ax=ax2, shrink=0.5, aspect=30, pad=0.05)


h3 = ax3.imshow(
    np.abs(Truth - preds), cmap="jet", aspect="auto", extent=extent, vmin=0.0, vmax=2e-3
)
ax3.set_title("Error")
ax3.set_xlabel("T")
ax3.set_ylabel("X")
figs.colorbar(h3, ax=ax3, shrink=0.5, aspect=30, pad=0.05)
plt.show()

# %%
rel2 = np.linalg.norm(Truth - preds, 2) / np.linalg.norm(Truth, 2)
print("ReL2: ", rel2)
# Out:
# ReL2:  8.127283167507813e-05

# %%
t = 0.98
x = np.linspace(-0.1, 0.1, 201)
t = np.ones(201) * t

indexs = datasets[:, 1] == 0.98
truth = Truth.flatten()[indexs]


dapt = np.concatenate([x.reshape(-1, 1), t.reshape(-1, 1)], 1)
preddd = (
    model(torch.tensor(dapt, dtype=torch.float32).cuda()).cpu().detach().numpy().ravel()
)

plt.figure(figsize=(6, 6))
plt.plot(np.linspace(-1, 1, 201), truth, "r-", label="Truth")
plt.plot(x, preddd, "b--", label="Pred")
plt.xlim(-0.1, 0.1)
plt.ylim(0, 1)
plt.legend()
plt.show()
